# %%
import tkinter as tk

# counter = 0

def button1_callback(): 
    # counter +=1 
    input_text = E1.get()  # ورودی انتری را در داخل لیبل نمایش مبدهد
    L1.config(text = f"E1 Text : {input_text}", fg = 'green')
    B1.config(text = f'Clicked ', bg= 'blue')
    # print(f"E1 Text : {input_text}")


window1  = tk.Tk()

L1 = tk.Label(window1, text = "Hello, Reza! Hasan")  # درست کردن ویجت
L2 = tk.Label(window1, text = "This is Label Number 2 ", background = "red" ) 
B1 = tk.Button(window1, text = "Register", command = button1_callback )  # به ویندویک ، مستر میگویند.  # هنگام فشرده دکمه تابع تعریف شده را صدا میزند.
E1 = tk.Entry(master = window1)




L1.pack()  # به صورت خودکار ویجت های جدید را در پنجره ویندو یک جای گذاری میکند 
L2.pack()
B1.pack()
E1.pack()

window1.mainloop()

# %%
import tkinter as tk

# counter = 0

def button1_callback(): 
   
    user_text = E1.get() 
    pass_text = E2.get() 
    if user_text == "Reza" and pass_text == "1234":
     B1.config(text = f'Log in is successful ', bg= 'blue')
    else:
        B1.config(text = f'Log in is Not successful ', bg= 'red')
    # print(f"E1 Text : {input_text}")


window1  = tk.Tk()
L0 = tk.Label(window1, text = "Log In The Form") 
L1 = tk.Label(window1, text = "Please Enter UserName: ") 
E1 = tk.Entry(master = window1)
L2 = tk.Label(window1, text = "Please Enter Your Password : ") 
E2 = tk.Entry(master = window1)
B1 = tk.Button(window1, text = "Sign In", command = button1_callback ) 


L0.pack()
L1.pack()  
L2.pack()
B1.pack()
E1.pack()
E2.pack()

window1.mainloop()

# %%
import tkinter as tk

counter = 0

def button1_callback(): 
    global counter  # روش اول برای استفاده از متغییر کانتر در GUI
    counter+=1 
    input_text = E1.get()  # ورودی انتری را در داخل لیبل نمایش مبدهد
    L1.config(text = f"E1 Text : {input_text}", fg = 'green')
    B1.config(text = f'Clicked {counter} times ', bg= 'blue')
    # print(f"E1 Text : {input_text}")


window1  = tk.Tk()

L1 = tk.Label(window1, text = "Hello, Reza! Hasan")  # درست کردن ویجت
L2 = tk.Label(window1, text = "This is Label Number 2 ", background = "red" ) 
B1 = tk.Button(window1, text = "Register", command = button1_callback )  # به ویندویک ، مستر میگویند.  # هنگام فشرده دکمه تابع تعریف شده را صدا میزند.
E1 = tk.Entry(master = window1)




L1.pack()  # به صورت خودکار ویجت های جدید را در پنجره ویندو یک جای گذاری میکند 
L2.pack()
B1.pack()
E1.pack()

window1.mainloop()

# %%
# روش دوم 

import tkinter as tk

window1  = tk.Tk()
counter = tk.IntVar(value = 0 ) # 1


def button1_callback(): 
    counter.set(counter.get() + 1)# 2 
    input_text = E1.get()  
    # L1.config(text = f"E1 Text : {input_text}", fg = 'green')
    l1_textvariable.set("Salamat")  # روش جدید مدیریت تکست با استفاده از متغیرهای تک اینتر با استفاده از متد ست
    B1.config(text = f'Clicked {counter.get()} times ', bg= 'blue') # 3  این سه خط روش دوم استفاده از کانتر هستند
    # print(f"E1 Text : {input_text}")



l1_textvariable = tk.StringVar(value = "L1 Value")
L1 = tk.Label(window1, textvariable = l1_textvariable)  # اگر متغیر قرار است تغییر کند به این شکل استفاده میکنیم و در غیر این صورت از کانفیگ مثل قبل استفاده میکنیم.
L2 = tk.Label(window1, text = "This is Label Number 2 ", background = "red" ) 
B1 = tk.Button(window1, text = "Register", command = button1_callback )  
E1 = tk.Entry(master = window1)




L1.pack()  
L2.pack()
B1.pack()
E1.pack()

window1.mainloop()

# %%
import tkinter as tk

app = tk.Tk()
result_text = tk.StringVar(app, value = "")  # در حالت پیش فرض خالی میگذاریم

def login_callback():
    username = username_entry.get()
    password = password_entry.get()
    if username == "admin" and password == "1234":
       result_text.set("Welcome")
    else:
        result_text.set(" Fail")   


username_lable = tk.Label(app,text = "Username: " )
username_entry = tk.Entry(app,)
password_lable = tk.Label(app, text = "PassWord: " )
password_entry = tk.Entry(app,)
login_button = tk.Button(app, text = "Login" , command = login_callback)
result_lablel = tk.Label(app, textvariable = result_text)  # چون تغییر میکند از جنس تکست وریبل تعریف میشود. 
username_lable.pack()
username_entry.pack()
password_lable.pack()
password_entry.pack()

login_button.pack()
result_lablel.pack()


app.mainloop()

# %%
# استفاده از Place , Grid

# %%
# در Place  مختصات ویجت را میدهیم

# %%
# جدول بندی صفحه ویندوز برای چیدمان  در گرید

# %%
# فریم گروه بندی ویجت ها است.

# %%
import tkinter as tk

app = tk.Tk()
result_text = tk.StringVar(app, value = "")  

def login_callback():
    username = username_entry.get()
    password = password_entry.get()
    if username == "admin" and password == "1234":
       result_text.set("Welcome")
    else:
        result_text.set(" Fail")   

login_frame = tk.Frame(app,  height= 200, width= 300,)

username_lable = tk.Label(login_frame,text = "Username: " )
username_entry = tk.Entry(login_frame,)
password_lable = tk.Label(login_frame, text = "PassWord: " )
password_entry = tk.Entry(login_frame,)
login_button = tk.Button(login_frame, text = "Login" , command = login_callback)
result_lablel = tk.Label(login_frame, textvariable = result_text)
username_lable.grid(row = 0, column = 0, padx = 5, pady = 5)  # پد برای فاصله گذاری است
# username_lable.pack()
username_entry.grid(row = 0, column = 1, padx = 5, pady = 5)
# username_entry.pack()
password_lable.grid(row = 1, column = 0, padx = 5, pady = 5)
# password_lable.pack()
password_entry.grid(row = 1, column = 1, padx = 5, pady = 5)  
# password_entry.pack()
login_button.grid(row = 2, column = 0, columnspan = 2)  # وسط چین میکندcolumnspan 
# login_button.pack()
result_lablel.grid(row = 3, column = 0, columnspan = 2)
login_frame.pack()

app.mainloop()

# %%
#  import tkinter as tk

app = tk.Tk()
result_text = tk.StringVar(app, value = "")  

def login_callback():
    username = username_entry.get()
    password = password_entry.get()
    if username == "admin" and password == "1234":
       result_text.set("Welcome")
    else:
        result_text.set(" Fail")   

login_frame = tk.Frame(app,  height= 200, width= 300, bg = 'blue')

username_lable = tk.Label(login_frame,text = "Username: " )
username_entry = tk.Entry(login_frame,)
password_lable = tk.Label(login_frame, text = "PassWord: " )
password_entry = tk.Entry(login_frame,)
login_button = tk.Button(login_frame, text = "Login" , command = login_callback)
result_lablel = tk.Label(login_frame, textvariable = result_text)
username_lable.grid(row = 0, column = 0, padx = 5, pady = 5)  # پد برای فاصله گذاری است
# username_lable.pack()
username_entry.grid(row = 0, column = 1, padx = 5, pady = 5)
# username_entry.pack()
password_lable.grid(row = 1, column = 0, padx = 5, pady = 5)
# password_lable.pack()
password_entry.grid(row = 1, column = 1, padx = 5, pady = 5)  
# password_entry.pack()
login_button.grid(row = 2, column = 0, columnspan = 2)  # وسط چین میکندcolumnspan 
# login_button.pack()
result_lablel.grid(row = 3, column = 0, columnspan = 2)
login_frame.pack()


login_frame2 = tk.Frame(app,  height= 200, width= 300, bg = 'red')

username_lable = tk.Label(login_frame2,text = "Username: " )
username_entry = tk.Entry(login_frame2,)
password_lable = tk.Label(login_frame2, text = "PassWord: " )
password_entry = tk.Entry(login_frame2,)
login_button = tk.Button(login_frame2, text = "Login" , command = login_callback)
result_lablel = tk.Label(login_frame2, textvariable = result_text)
username_lable.grid(row = 0, column = 0, padx = 5, pady = 5)  # پد برای فاصله گذاری است
# username_lable.pack()
username_entry.grid(row = 0, column = 1, padx = 5, pady = 5)
# username_entry.pack()
password_lable.grid(row = 1, column = 0, padx = 5, pady = 5)
# password_lable.pack()
password_entry.grid(row = 1, column = 1, padx = 5, pady = 5)  
# password_entry.pack()
login_button.grid(row = 2, column = 0, columnspan = 2)  # وسط چین میکندcolumnspan 
# login_button.pack()
result_lablel.grid(row = 3, column = 0, columnspan = 2)
login_frame2.place(x=1 , y =1)
# login_frame2.place(relheight=1) # کل عرض پنجره را میگیرد


b1 = tk.Button(app, text = 'page1', command = lambda: login_frame.tkraise()) # اگر فریم ها روی هم بیفتد با زدن دکمه پیج یک ، فریمی که عقب افتاده میاید جلو
b2 = tk.Button(app, text = 'page2', command = lambda: login_frame2.tkraise())
b1.pack()
b2.pack()

app.mainloop()

# %%
#  import tkinter as tk

app = tk.Tk()
result_text = tk.StringVar(app, value = "")  

def login_callback():
    username = username_entry.get()
    password = password_entry.get()
    if username == "admin" and password == "1234":
       result_text.set("Welcome")
    else:
        result_text.set(" Fail")   

login_frame = tk.Frame(app,  height= 200, width= 300, bg = 'blue')

username_lable = tk.Label(login_frame,text = "Username: " )
username_entry = tk.Entry(login_frame,)
password_lable = tk.Label(login_frame, text = "PassWord: " )
password_entry = tk.Entry(login_frame,)
login_button = tk.Button(login_frame, text = "Login" , command = login_callback)
result_lablel = tk.Label(login_frame, textvariable = result_text)
username_lable.grid(row = 0, column = 0, padx = 5, pady = 5)  # پد برای فاصله گذاری است
# username_lable.pack()
username_entry.grid(row = 0, column = 1, padx = 5, pady = 5)
# username_entry.pack()
password_lable.grid(row = 1, column = 0, padx = 5, pady = 5)
# password_lable.pack()
password_entry.grid(row = 1, column = 1, padx = 5, pady = 5)  
# password_entry.pack()
login_button.grid(row = 2, column = 0, columnspan = 2)  # وسط چین میکندcolumnspan 
# login_button.pack()
result_lablel.grid(row = 3, column = 0, columnspan = 2)
login_frame.place(x=0,y=0 )

class Student:
    def __init__(self, courses:list[str]):
        self.courses = courses

    def get_frame(self):
        frame = tk.Frame(app, bg = 'red', height = 200, width = 100)
        for course in self.courses:
           l = tk.Label(frame, text = course)
           l.pack()
        return frame


s = Student(["Math","Chemistry","Physics"])

f = s.get_frame()
f.place(x = 0 , y = 0)


b1 = tk.Button(app, text = 'page1', command = lambda: login_frame.tkraise())
b2 = tk.Button(app, text = 'page2', command = lambda: f.tkraise())
b1.pack()
b2.pack()

app.mainloop()

# %%
#  import tkinter as tk

app = tk.Tk()
result_text = tk.StringVar(app, value = "")  

def login_callback():
    username = username_entry.get()
    password = password_entry.get()
    if username == "admin" and password == "1234":
       result_text.set("Welcome")
    else:
        result_text.set(" Fail")   

login_frame = tk.Frame(app,  height= 200, width= 300, bg = 'blue')

username_lable = tk.Label(login_frame,text = "Username: " )
username_entry = tk.Entry(login_frame,)
password_lable = tk.Label(login_frame, text = "PassWord: " )
password_entry = tk.Entry(login_frame,)
login_button = tk.Button(login_frame, text = "Login" , command = login_callback)
result_lablel = tk.Label(login_frame, textvariable = result_text)
username_lable.grid(row = 0, column = 0, padx = 5, pady = 5)  # پد برای فاصله گذاری است
# username_lable.pack()
username_entry.grid(row = 0, column = 1, padx = 5, pady = 5)
# username_entry.pack()
password_lable.grid(row = 1, column = 0, padx = 5, pady = 5)
# password_lable.pack()
password_entry.grid(row = 1, column = 1, padx = 5, pady = 5)  
# password_entry.pack()
login_button.grid(row = 2, column = 0, columnspan = 2)  # وسط چین میکندcolumnspan 
# login_button.pack()
result_lablel.grid(row = 3, column = 0, columnspan = 2)
# login_frame.place(x=0,y=0 )
login_frame.pack()

class Student:
    def __init__(self, courses:list[str]):
        self.courses = courses

    def get_frame(self):
        frame = tk.Frame(app, bg = 'red', height = 200, width = 100)
        for i,course in enumerate(self.courses):
           l = tk.Label(frame, text = course)
           l.grid(row = i , column = 0, padx = 50, pady = 5 )
        return frame


s = Student(["Math","Chemistry","Physics"])

f = s.get_frame()
# f.place(x = 0 , y = 0)
f.pack()


# b1 = tk.Button(app, text = 'page1', command = lambda: login_frame.tkraise())
# b2 = tk.Button(app, text = 'page2', command = lambda: f.tkraise())
# b1.pack()
# b2.pack()

app.mainloop()

# %%
import tkinter as tk

app = tk.Tk()
result_text = tk.StringVar(app, value = "")  

def login_callback():
    username = username_entry.get()
    password = password_entry.get()
    if username == "admin" and password == "1234":
       result_text.set("Welcome")
       f.tkraise()
    else:
        result_text.set(" Access is Denied")   

login_frame = tk.Frame(app,  height= 200, width= 300,)

username_lable = tk.Label(login_frame,text = "Username: " )
username_entry = tk.Entry(login_frame,)
password_lable = tk.Label(login_frame, text = "PassWord: " )
password_entry = tk.Entry(login_frame,)
login_button = tk.Button(login_frame, text = "Login" , command = login_callback)
result_lablel = tk.Label(login_frame, textvariable = result_text)
username_lable.grid(row = 0, column = 0, padx = 5, pady = 5)  # پد برای فاصله گذاری است
# username_lable.pack()
username_entry.grid(row = 0, column = 1, padx = 5, pady = 5)
# username_entry.pack()
password_lable.grid(row = 1, column = 0, padx = 5, pady = 5)
# password_lable.pack()
password_entry.grid(row = 1, column = 1, padx = 5, pady = 5)  
# password_entry.pack()
login_button.grid(row = 2, column = 0, columnspan = 2)  # وسط چین میکندcolumnspan 
# login_button.pack()
result_lablel.grid(row = 3, column = 0, columnspan = 2)
login_frame.pack()


class Student:
    def __init__(self, courses:list[str]):
        self.courses = courses

    def get_frame(self):
        frame = tk.Frame(app, bg = 'red', height = 200, width = 100)
        for i,course in enumerate(self.courses):
           l = tk.Label(frame, text = course)
           l.grid(row = i , column = 0, padx = 50, pady = 5 )
        return frame


s = Student(["Math","Chemistry","Physics"])

f = s.get_frame()
f.place(x = 0 , y = 0, relheight=1, relwidth=1)

login_frame.place(x = 0 , y = 0, relheight=1, relwidth=1)
login_frame.tkraise()



app.mainloop()
